# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyApNtJPkiFGq9cK2W_8iPEzUGGBMoB2AB0")

# %%
model= genai.GenerativeModel("gemini-2.5-flash")
response = model.generate_content("what is Artificial Intelligence?")
print(response.text)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.display_name)

# %%
context = "I have incorporated NLP in my PCOS detection website and created a chatbot called Fembot."

question = "Your question here"

response = model.generate_content(
    f"Context: {context}\nQuestion: {question}"
)

print(response.text)

# %%
domain = "education"
question = "Explain machine learning in simple terms"

response = model.generate_content(
    f"You are an expert assistant in the {domain} domain.\n"
    f"Answer the following question clearly and simply:\n"
    f"Question: {question}"
)

print(response.text)

# %%
Role = "Expert in Renewable Energy"
Course_Name = "The Future of Renewable Energy"
Audience = "Students & Beginners"
Format = "Module-based with examples, case studies, and MCQs"
Tone = "Simple, engaging, beginner-friendly"
response = model.generate_content(
    f"You are a {Role}. Explain {Course_Name} for {Audience}. format: {Format} Tone: {Tone}"
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5704/1789336439.py in <cell line: 0>()
#       4 Format = "Module-based with examples, case studies, and MCQs"
#       5 Tone = "Simple, engaging, beginner-friendly"
# ----> 6 response = model.generate_content(
#       7     f"You are a {Role}. Explain {Course_Name} for {Audience}. format: {Format} Tone: {Tone}"
#       8 )
#
# NameError: name 'model' is not defined
